# %% [markdown]
# ## Gradient-weighted Regression Activation Maps (Grad-RAM)

# %%
from __future__ import print_function
import os
import numpy as np
import sys
import cv2
import scipy.io as sio
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Lambda, Concatenate, Add, Maximum, Average
from keras.layers import Conv2D, Input, MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.models import Model
from keras.layers.core import Lambda
from keras.preprocessing import image

# %%
batch_size = 128
epochs = 10

# %% [markdown]
# ## Load Data

# %%
dir_name = 'processed_data/expressive_data/'

density = '08'

# load train data

fname = 'x_train_expressive_density_' + density + '.mat'
filename = os.path.join(os.getcwd(),dir_name,fname)
x_train_mat = sio.loadmat(filename)['x_train_expressive_mat']
x_train_mat = np.float32(x_train_mat)

fname = 'y_train_expressive_density_' + density + '.mat'
filename = os.path.join(os.getcwd(),dir_name,fname)
y_train_mat = sio.loadmat(filename)['y_train_expressive_mat']
y_train_mat = np.float32(y_train_mat)

# load test data
fname = 'x_test_expressive_density_' + density + '.mat'
filename = os.path.join(os.getcwd(),dir_name,fname)
x_test_mat = sio.loadmat(filename)['x_test_expressive_mat']
x_test_mat = np.float32(x_test_mat)

fname = 'y_test_expressive_density_' + density + '.mat'
filename = os.path.join(os.getcwd(),dir_name,fname)
y_test_mat = sio.loadmat(filename)['y_test_expressive_mat']
y_test_mat = np.float32(y_test_mat)

print('x_train_mat_shape:',x_train_mat.shape)
print('x_test_mat_shape:',x_test_mat.shape)
print('y_train_mat_shape:',y_train_mat.shape)
print('y_test_mat_shape:',y_test_mat.shape)


# Form training and testing data

x_train = np.zeros((x_train_mat.shape[2],116,116,1),dtype=np.float32)
y_train = np.zeros((x_train_mat.shape[2],1),dtype=np.float32)

x_test = np.zeros((x_test_mat.shape[2],116,116,1),dtype=np.float32)
y_test = np.zeros((x_test_mat.shape[2],1),dtype=np.float32)


for i in range(x_train_mat.shape[2]):
    x_train[i,:,:,0] = x_train_mat[:,:,i]
    y_train[i,0] = y_train_mat[i,0] # EXPRESSIVE SCORE
        
for i in range(x_test_mat.shape[2]):
    x_test[i,:,:,0] = x_test_mat[:,:,i]
    y_test[i,0] = y_test_mat[i,0]  # EXPRESSIVE SCORE
    
print('x_train_shape:',x_train.shape)
print('x_test_shape:',x_test.shape)
print('y_train_shape:',y_train.shape)
print('y_test_shape:',y_test.shape)
# Out:
# x_train_mat_shape: (116, 116, 17374)
# x_test_mat_shape: (116, 116, 8687)
# y_train_mat_shape: (17374, 1)
# y_test_mat_shape: (8687, 1)
# x_train_shape: (17374, 116, 116, 1)
# x_test_shape: (8687, 116, 116, 1)
# y_train_shape: (17374, 1)
# y_test_shape: (8687, 1)

# %%
# Reshape input
print(x_train.shape)
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
input_shape = (x_train.shape[1], x_train.shape[2], 1)

print('x_train_shape:',x_train.shape)
print('x_test_shape:',x_test.shape)
print('input_shape:',input_shape)
# Out:
# (17374, 116, 116, 1)
# x_train_shape: (17374, 116, 116, 1)
# x_test_shape: (8687, 116, 116, 1)
# input_shape: (116, 116, 1)

# %% [markdown]
# ## Define Dilated CNN + RN Model

# %%
## Define dilated CNN
d_rate = 2 # dilation rate

# Define 4 convolutional layers
def ConvolutionNetworks(no_filters=32, kernel_size=3, stride_size=1):
    def conv(model):
        model = Conv2D(no_filters, (3,3), strides=(stride_size,stride_size), activation='relu', input_shape=input_shape, data_format='channels_last')(model)
        model = MaxPooling2D()(model)
        model = BatchNormalization()(model)
        
        model = Conv2D(no_filters, (3,3), strides=(stride_size,stride_size), activation='relu')(model)
        model = MaxPooling2D()(model)
        model = BatchNormalization()(model)
        
        model = Conv2D(no_filters, (3,3), strides=(stride_size,stride_size), dilation_rate=(d_rate,d_rate), activation='relu')(model)
        model = MaxPooling2D()(model)
        model = BatchNormalization()(model)
        
        model = Conv2D(no_filters, (3,3), strides=(stride_size,stride_size), dilation_rate=(d_rate,d_rate), activation='relu')(model) # d=3
        #model = Conv2D(16, (3,3), strides=(stride_size,stride_size), activation='relu')(model) # d=4
        model = MaxPooling2D()(model)
        model = BatchNormalization()(model)
        
        return model
    return conv

# %%
# Define function to compute relations from objects - the following uses just 4 Lambda layers - O(n^2) time complexity

def compute_relations(objects):
    
    def get_top_dim_1(t):
        return t[:,0,:,:]
    
    def get_all_but_top_dim_1(t):
        return t[:,1:,:,:]
    
    def get_top_dim_2(t):
        return t[:,0,:]
    
    def get_all_but_top_dim_2(t):
        return t[:,1:,:]
    
    slice_top_dim_1 = Lambda(get_top_dim_1)
    slice_all_but_top_dim_1 = Lambda(get_all_but_top_dim_1)
    slice_top_dim_2 = Lambda(get_top_dim_2)
    slice_all_but_top_dim_2 = Lambda(get_all_but_top_dim_2)
    
    d = K.int_shape(objects)[2]
    print('d = ', d)
    features = []
    
    for i in range(d):
        features1 = slice_top_dim_1(objects)
        objects = slice_all_but_top_dim_1(objects)
        
        for j in range(d):
            features2 = slice_top_dim_2(features1)
            features1 = slice_all_but_top_dim_2(features1)
            features.append(features2)
            
    relations = []
    concat = Concatenate()
    for feature1 in features:
        for feature2 in features:
            if (features.index(feature1) < features.index(feature2)): # remove symmetric and self-relations
                relations.append(concat([feature1,feature2]))
                    
            
    return relations

# %%
# Baseline model - f(theta) of RN
def f_theta():
    def f(model):
        model = Dense(512)(model)
        model = Activation('relu')(model)
        model = Dropout(0.5)(model)
        
        model = Dense(512)(model)
        model = Activation('relu')(model)
        model = Dropout(0.5)(model)
        
        model = Dense(512)(model)
        model = Activation('relu')(model)
        
        #model = Dense(100)(model)
        #model = Activation('relu')(model)
        
        return model
    return f

# %%
def g_th(layers):
    def f(model):
        for n in range(len(layers)):
            model = layers[n](model)
        return model
    return f

def stack_layer(layers):
    def f(x):
        for k in range(len(layers)):
            x = layers[k](x)
        return x
    return f

# Define g(theta) of RN model
def g_theta(units=512, layers=4):
    r = []
    for k in range(layers):
        r.append(Dense(units))
        r.append(Activation('relu'))
    return g_th(r)

def get_MLP():
    return g_th()

# %%
# Define the main RN
    
def RelationNetworks(objects):
    g_t = g_theta()
    relations = compute_relations(objects)
    print('No of Relations:', len(relations))
    #print(relations)
    
    g_all = []
    
    for i, r in enumerate(relations):
        g_all.append(g_t(r))
        
    # combine to make the network combinatorially generalizable
    #combined_relation = Add()(g_all)
    combined_relation = Maximum()(g_all) # max pooling gave best results
    #combined_relation = Average()(g_all)
    
    f_out = f_theta()(combined_relation)
    return f_out

# %%
# build tag to identify objects in the image
def build_tag(conv):
    d = K.int_shape(conv)[2]
    tag = np.zeros((d,d,2))
    
    for i in range(d):
        for j in range(d):
            tag[i,j,0] = float(int(i%d))/(d-1)*2-1
            tag[i,j,1] = float(int(j%d))/(d-1)*2-1
            
    tag = K.variable(tag)
    tag = K.expand_dims(tag, axis=0)
    batch_size = K.shape(conv)[0]
    tag = K.tile(tag, [batch_size,1,1,1])
    
    return Input(tensor=tag)

# %%
# Construct the model
input_img = Input((x_train.shape[1], x_train.shape[2], 1))  

print('Input_image',input_img.shape)

img_after_conv = ConvolutionNetworks()(input_img) 
#tag = build_tag(img_after_conv)
#img_after_conv = Concatenate()([tag, img_after_conv])

img_after_RN = RelationNetworks(img_after_conv)

img_out = Dense(1, activation='linear')(img_after_RN)

#RN_model = Model(inputs=[input_img, tag], outputs=img_out)

RN_model = Model(inputs=[input_img], outputs=img_out)

print(RN_model.summary())
# Out:
# Input_image (?, 116, 116, 1)
# d =  3
# No of Relations: 36
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 116, 116, 1)  0
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 114, 114, 32) 320         input_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 57, 57, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 57, 57, 32)   128         max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 55, 55, 32)   9248        batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 27, 27, 32)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 27, 27, 32)   128         max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 23, 23, 32)   9248        batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 11, 11, 32)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 11, 11, 32)   128         max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 7, 7, 32)     9248        batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 3, 3, 32)     0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 3, 3, 32)     128         max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 3, 32)        0           batch_normalization_32[0][0]
#                                                                  lambda_30[0][0]
#                                                                  lambda_30[1][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              multiple             0           batch_normalization_32[0][0]
#                                                                  lambda_30[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              multiple             0           lambda_29[0][0]
#                                                                  lambda_32[0][0]
#                                                                  lambda_29[1][0]
#                                                                  lambda_32[3][0]
#                                                                  lambda_29[2][0]
#                                                                  lambda_32[6][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 32)           0           lambda_29[0][0]
#                                                                  lambda_32[0][0]
#                                                                  lambda_32[1][0]
#                                                                  lambda_29[1][0]
#                                                                  lambda_32[3][0]
#                                                                  lambda_32[4][0]
#                                                                  lambda_29[2][0]
#                                                                  lambda_32[6][0]
#                                                                  lambda_32[7][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64)           0           lambda_31[0][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_31[8][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[1][0]
#                                                                  lambda_31[8][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[2][0]
#                                                                  lambda_31[8][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[3][0]
#                                                                  lambda_31[8][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[4][0]
#                                                                  lambda_31[8][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[5][0]
#                                                                  lambda_31[8][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[6][0]
#                                                                  lambda_31[8][0]
#                                                                  lambda_31[7][0]
#                                                                  lambda_31[8][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 512)          33280       concatenate_15[0][0]
#                                                                  concatenate_15[1][0]
#                                                                  concatenate_15[2][0]
#                                                                  concatenate_15[3][0]
#                                                                  concatenate_15[4][0]
#                                                                  concatenate_15[5][0]
#                                                                  concatenate_15[6][0]
#                                                                  concatenate_15[7][0]
#                                                                  concatenate_15[8][0]
#                                                                  concatenate_15[9][0]
#                                                                  concatenate_15[10][0]
#                                                                  concatenate_15[11][0]
#                                                                  concatenate_15[12][0]
#                                                                  concatenate_15[13][0]
#                                                                  concatenate_15[14][0]
#                                                                  concatenate_15[15][0]
#                                                                  concatenate_15[16][0]
#                                                                  concatenate_15[17][0]
#                                                                  concatenate_15[18][0]
#                                                                  concatenate_15[19][0]
#                                                                  concatenate_15[20][0]
#                                                                  concatenate_15[21][0]
#                                                                  concatenate_15[22][0]
#                                                                  concatenate_15[23][0]
#                                                                  concatenate_15[24][0]
#                                                                  concatenate_15[25][0]
#                                                                  concatenate_15[26][0]
#                                                                  concatenate_15[27][0]
#                                                                  concatenate_15[28][0]
#                                                                  concatenate_15[29][0]
#                                                                  concatenate_15[30][0]
#                                                                  concatenate_15[31][0]
#                                                                  concatenate_15[32][0]
#                                                                  concatenate_15[33][0]
#                                                                  concatenate_15[34][0]
#                                                                  concatenate_15[35][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 512)          0           dense_57[0][0]
#                                                                  dense_57[1][0]
#                                                                  dense_57[2][0]
#                                                                  dense_57[3][0]
#                                                                  dense_57[4][0]
#                                                                  dense_57[5][0]
#                                                                  dense_57[6][0]
#                                                                  dense_57[7][0]
#                                                                  dense_57[8][0]
#                                                                  dense_57[9][0]
#                                                                  dense_57[10][0]
#                                                                  dense_57[11][0]
#                                                                  dense_57[12][0]
#                                                                  dense_57[13][0]
#                                                                  dense_57[14][0]
#                                                                  dense_57[15][0]
#                                                                  dense_57[16][0]
#                                                                  dense_57[17][0]
#                                                                  dense_57[18][0]
#                                                                  dense_57[19][0]
#                                                                  dense_57[20][0]
#                                                                  dense_57[21][0]
#                                                                  dense_57[22][0]
#                                                                  dense_57[23][0]
#                                                                  dense_57[24][0]
#                                                                  dense_57[25][0]
#                                                                  dense_57[26][0]
#                                                                  dense_57[27][0]
#                                                                  dense_57[28][0]
#                                                                  dense_57[29][0]
#                                                                  dense_57[30][0]
#                                                                  dense_57[31][0]
#                                                                  dense_57[32][0]
#                                                                  dense_57[33][0]
#                                                                  dense_57[34][0]
#                                                                  dense_57[35][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 512)          262656      activation_50[0][0]
#                                                                  activation_50[1][0]
#                                                                  activation_50[2][0]
#                                                                  activation_50[3][0]
#                                                                  activation_50[4][0]
#                                                                  activation_50[5][0]
#                                                                  activation_50[6][0]
#                                                                  activation_50[7][0]
#                                                                  activation_50[8][0]
#                                                                  activation_50[9][0]
#                                                                  activation_50[10][0]
#                                                                  activation_50[11][0]
#                                                                  activation_50[12][0]
#                                                                  activation_50[13][0]
#                                                                  activation_50[14][0]
#                                                                  activation_50[15][0]
#                                                                  activation_50[16][0]
#                                                                  activation_50[17][0]
#                                                                  activation_50[18][0]
#                                                                  activation_50[19][0]
#                                                                  activation_50[20][0]
#                                                                  activation_50[21][0]
#                                                                  activation_50[22][0]
#                                                                  activation_50[23][0]
#                                                                  activation_50[24][0]
#                                                                  activation_50[25][0]
#                                                                  activation_50[26][0]
#                                                                  activation_50[27][0]
#                                                                  activation_50[28][0]
#                                                                  activation_50[29][0]
#                                                                  activation_50[30][0]
#                                                                  activation_50[31][0]
#                                                                  activation_50[32][0]
#                                                                  activation_50[33][0]
#                                                                  activation_50[34][0]
#                                                                  activation_50[35][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 512)          0           dense_58[0][0]
#                                                                  dense_58[1][0]
#                                                                  dense_58[2][0]
#                                                                  dense_58[3][0]
#                                                                  dense_58[4][0]
#                                                                  dense_58[5][0]
#                                                                  dense_58[6][0]
#                                                                  dense_58[7][0]
#                                                                  dense_58[8][0]
#                                                                  dense_58[9][0]
#                                                                  dense_58[10][0]
#                                                                  dense_58[11][0]
#                                                                  dense_58[12][0]
#                                                                  dense_58[13][0]
#                                                                  dense_58[14][0]
#                                                                  dense_58[15][0]
#                                                                  dense_58[16][0]
#                                                                  dense_58[17][0]
#                                                                  dense_58[18][0]
#                                                                  dense_58[19][0]
#                                                                  dense_58[20][0]
#                                                                  dense_58[21][0]
#                                                                  dense_58[22][0]
#                                                                  dense_58[23][0]
#                                                                  dense_58[24][0]
#                                                                  dense_58[25][0]
#                                                                  dense_58[26][0]
#                                                                  dense_58[27][0]
#                                                                  dense_58[28][0]
#                                                                  dense_58[29][0]
#                                                                  dense_58[30][0]
#                                                                  dense_58[31][0]
#                                                                  dense_58[32][0]
#                                                                  dense_58[33][0]
#                                                                  dense_58[34][0]
#                                                                  dense_58[35][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 512)          262656      activation_51[0][0]
#                                                                  activation_51[1][0]
#                                                                  activation_51[2][0]
#                                                                  activation_51[3][0]
#                                                                  activation_51[4][0]
#                                                                  activation_51[5][0]
#                                                                  activation_51[6][0]
#                                                                  activation_51[7][0]
#                                                                  activation_51[8][0]
#                                                                  activation_51[9][0]
#                                                                  activation_51[10][0]
#                                                                  activation_51[11][0]
#                                                                  activation_51[12][0]
#                                                                  activation_51[13][0]
#                                                                  activation_51[14][0]
#                                                                  activation_51[15][0]
#                                                                  activation_51[16][0]
#                                                                  activation_51[17][0]
#                                                                  activation_51[18][0]
#                                                                  activation_51[19][0]
#                                                                  activation_51[20][0]
#                                                                  activation_51[21][0]
#                                                                  activation_51[22][0]
#                                                                  activation_51[23][0]
#                                                                  activation_51[24][0]
#                                                                  activation_51[25][0]
#                                                                  activation_51[26][0]
#                                                                  activation_51[27][0]
#                                                                  activation_51[28][0]
#                                                                  activation_51[29][0]
#                                                                  activation_51[30][0]
#                                                                  activation_51[31][0]
#                                                                  activation_51[32][0]
#                                                                  activation_51[33][0]
#                                                                  activation_51[34][0]
#                                                                  activation_51[35][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 512)          0           dense_59[0][0]
#                                                                  dense_59[1][0]
#                                                                  dense_59[2][0]
#                                                                  dense_59[3][0]
#                                                                  dense_59[4][0]
#                                                                  dense_59[5][0]
#                                                                  dense_59[6][0]
#                                                                  dense_59[7][0]
#                                                                  dense_59[8][0]
#                                                                  dense_59[9][0]
#                                                                  dense_59[10][0]
#                                                                  dense_59[11][0]
#                                                                  dense_59[12][0]
#                                                                  dense_59[13][0]
#                                                                  dense_59[14][0]
#                                                                  dense_59[15][0]
#                                                                  dense_59[16][0]
#                                                                  dense_59[17][0]
#                                                                  dense_59[18][0]
#                                                                  dense_59[19][0]
#                                                                  dense_59[20][0]
#                                                                  dense_59[21][0]
#                                                                  dense_59[22][0]
#                                                                  dense_59[23][0]
#                                                                  dense_59[24][0]
#                                                                  dense_59[25][0]
#                                                                  dense_59[26][0]
#                                                                  dense_59[27][0]
#                                                                  dense_59[28][0]
#                                                                  dense_59[29][0]
#                                                                  dense_59[30][0]
#                                                                  dense_59[31][0]
#                                                                  dense_59[32][0]
#                                                                  dense_59[33][0]
#                                                                  dense_59[34][0]
#                                                                  dense_59[35][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 512)          262656      activation_52[0][0]
#                                                                  activation_52[1][0]
#                                                                  activation_52[2][0]
#                                                                  activation_52[3][0]
#                                                                  activation_52[4][0]
#                                                                  activation_52[5][0]
#                                                                  activation_52[6][0]
#                                                                  activation_52[7][0]
#                                                                  activation_52[8][0]
#                                                                  activation_52[9][0]
#                                                                  activation_52[10][0]
#                                                                  activation_52[11][0]
#                                                                  activation_52[12][0]
#                                                                  activation_52[13][0]
#                                                                  activation_52[14][0]
#                                                                  activation_52[15][0]
#                                                                  activation_52[16][0]
#                                                                  activation_52[17][0]
#                                                                  activation_52[18][0]
#                                                                  activation_52[19][0]
#                                                                  activation_52[20][0]
#                                                                  activation_52[21][0]
#                                                                  activation_52[22][0]
#                                                                  activation_52[23][0]
#                                                                  activation_52[24][0]
#                                                                  activation_52[25][0]
#                                                                  activation_52[26][0]
#                                                                  activation_52[27][0]
#                                                                  activation_52[28][0]
#                                                                  activation_52[29][0]
#                                                                  activation_52[30][0]
#                                                                  activation_52[31][0]
#                                                                  activation_52[32][0]
#                                                                  activation_52[33][0]
#                                                                  activation_52[34][0]
#                                                                  activation_52[35][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 512)          0           dense_60[0][0]
#                                                                  dense_60[1][0]
#                                                                  dense_60[2][0]
#                                                                  dense_60[3][0]
#                                                                  dense_60[4][0]
#                                                                  dense_60[5][0]
#                                                                  dense_60[6][0]
#                                                                  dense_60[7][0]
#                                                                  dense_60[8][0]
#                                                                  dense_60[9][0]
#                                                                  dense_60[10][0]
#                                                                  dense_60[11][0]
#                                                                  dense_60[12][0]
#                                                                  dense_60[13][0]
#                                                                  dense_60[14][0]
#                                                                  dense_60[15][0]
#                                                                  dense_60[16][0]
#                                                                  dense_60[17][0]
#                                                                  dense_60[18][0]
#                                                                  dense_60[19][0]
#                                                                  dense_60[20][0]
#                                                                  dense_60[21][0]
#                                                                  dense_60[22][0]
#                                                                  dense_60[23][0]
#                                                                  dense_60[24][0]
#                                                                  dense_60[25][0]
#                                                                  dense_60[26][0]
#                                                                  dense_60[27][0]
#                                                                  dense_60[28][0]
#                                                                  dense_60[29][0]
#                                                                  dense_60[30][0]
#                                                                  dense_60[31][0]
#                                                                  dense_60[32][0]
#                                                                  dense_60[33][0]
#                                                                  dense_60[34][0]
#                                                                  dense_60[35][0]
# __________________________________________________________________________________________________
# maximum_8 (Maximum)             (None, 512)          0           activation_53[0][0]
#                                                                  activation_53[1][0]
#                                                                  activation_53[2][0]
#                                                                  activation_53[3][0]
#                                                                  activation_53[4][0]
#                                                                  activation_53[5][0]
#                                                                  activation_53[6][0]
#                                                                  activation_53[7][0]
#                                                                  activation_53[8][0]
#                                                                  activation_53[9][0]
#                                                                  activation_53[10][0]
#                                                                  activation_53[11][0]
#                                                                  activation_53[12][0]
#                                                                  activation_53[13][0]
#                                                                  activation_53[14][0]
#                                                                  activation_53[15][0]
#                                                                  activation_53[16][0]
#                                                                  activation_53[17][0]
#                                                                  activation_53[18][0]
#                                                                  activation_53[19][0]
#                                                                  activation_53[20][0]
#                                                                  activation_53[21][0]
#                                                                  activation_53[22][0]
#                                                                  activation_53[23][0]
#                                                                  activation_53[24][0]
#                                                                  activation_53[25][0]
#                                                                  activation_53[26][0]
#                                                                  activation_53[27][0]
#                                                                  activation_53[28][0]
#                                                                  activation_53[29][0]
#                                                                  activation_53[30][0]
#                                                                  activation_53[31][0]
#                                                                  activation_53[32][0]
#                                                                  activation_53[33][0]
#                                                                  activation_53[34][0]
#                                                                  activation_53[35][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 512)          262656      maximum_8[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 512)          0           dense_61[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           activation_54[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 512)          262656      dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 512)          0           dense_62[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 512)          0           activation_55[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 512)          262656      dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 512)          0           dense_63[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 1)            513         activation_56[0][0]
# ==================================================================================================
# Total params: 1,638,305
# Trainable params: 1,638,049
# Non-trainable params: 256
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Compile and Test Model

# %%
#compile model
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

RN_model.compile(optimizer=adam, loss='mse', metrics=['mae','mape'])


# Train Model
RN_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)

# Save the trained Model
RN_model.save_weights('RN_model_weights.h5')

with open('RN_model_architecture.json','w') as f:
    f.write(RN_model.to_json())

# Test Model
y_test_pred = RN_model.predict(x_test)

print(y_test.shape)
print('y_test:', y_test)


print(y_test_pred.shape)
print('y_test_pred:', y_test_pred)


# Print Results
print('mae: ', np.mean(np.abs(y_test - y_test_pred)))
print('sdae: ', np.std(np.abs(y_test - y_test_pred)))

count = 0
for i in range(len(y_test)):
    if (np.abs(y_test[i] - y_test_pred[i])) < 0.125: # prob of mae less than 15 - 15/120 = 0.125
        count += 1
        
prob_error = count / len(y_test)

print('prob of mae less than 0.125: ', prob_error)
# Out:
# Epoch 1/10
# 17374/17374 [==============================] - 17s 959us/step - loss: 0.0534 - mean_absolute_error: 0.1813 - mean_absolute_percentage_error: 29.2885
# Epoch 2/10
# 17374/17374 [==============================] - 9s 491us/step - loss: 0.0170 - mean_absolute_error: 0.1013 - mean_absolute_percentage_error: 15.9951
# Epoch 3/10
# 17374/17374 [==============================] - 8s 489us/step - loss: 0.0090 - mean_absolute_error: 0.0732 - mean_absolute_percentage_error: 11.2984
# Epoch 4/10
# 17374/17374 [==============================] - 8s 488us/step - loss: 0.0062 - mean_absolute_error: 0.0611 - mean_absolute_percentage_error: 9.2508
# Epoch 5/10
# 17374/17374 [==============================] - 9s 492us/step - loss: 0.0057 - mean_absolute_error: 0.0584 - mean_absolute_percentage_error: 8.8517
# Epoch 6/10
# 17374/17374 [==============================] - 8s 488us/step - loss: 0.0048 - mean_absolute_error: 0.0534 - mean_absolute_percentage_error: 8.0206
# Epoch 7/10
# 17374/17374 [==============================] - 9s 491us/step - loss: 0.0042 - mean_absolute_error: 0.0500 - mean_absolute_percentage_error: 7.4828
# Epoch 8/10
# 17374/17374 [==============================] - 9s 490us/step - loss: 0.0033 - mean_absolute_error: 0.0440 - mean_absolute_percentage_error: 6.5318
# Epoch 9/10
# 17374/17374 [==============================] - 8s 488us/step - loss: 0.0032 - mean_absolute_error: 0.0430 - mean_absolute_percentage_error: 6.3386
# Epoch 10/10
# 17374/17374 [==============================] - 8s 486us/step - loss: 0.0031 - mean_absolute_error: 0.0421 - mean_absolute_percentage_error: 6.2036
# (8687, 1)
# y_test: [[0.425     ]
#  [0.7416667 ]
#  [0.7583333 ]
#  ...
#  [0.49353933]
#  [0.5328431 ]
#  [0.4979689 ]]
# (8687, 1)
# y_test_pred: [[0.40307313]
#  [0.5544771 ]
#  [0.58039826]
#  ...
#  [0.4247951 ]
#  [0.46159256]
#  [0.4210567 ]]
# mae:  0.1577076
# sdae:  0.08269314
# prob of mae less than 0.125:  0.35248071831472316

# %%
import json
from keras.models import model_from_json, load_model

print('x_test_shape:',x_test.shape)

#x_test = x_test.reshape(x_test.shape[1], x_test.shape[2], x_test.shape[0])

#print('x_test_shape:',x_test.shape)

print(type(x_test.dtype))

x_test = np.asarray(x_test)
print('x_test_shape:',x_test.shape)
print(type(x_test.dtype))

x_test_img = x_test[0,:,:,:]
print('x_test_img_shape:',x_test_img.shape)
# Out:
# x_test_shape: (8687, 116, 116, 1)
# <class 'numpy.dtype'>
# x_test_shape: (8687, 116, 116, 1)
# <class 'numpy.dtype'>
# x_test_img_shape: (116, 116, 1)

# %%
from keras.preprocessing import image

# %%
## Load pretrained Model
with open('RN_model_architecture.json', 'r') as f:
    RN_model = model_from_json(f.read())

RN_model.load_weights('RN_model_weights.h5')

#compile model
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

RN_model.compile(optimizer=adam, loss='mse', metrics=['mae','mape'])


#test_img = image.img_to_array(x_test[:,:,0])
#print('test_img_shape:',test_img.shape)
#print(type(test_img.dtype))


#test_img = np.expand_dims(test_img, axis=0)

# Test Model
y_test_pred = RN_model.predict(x_test)

print(y_test_pred)
# Out:
# [[0.40307313]
#  [0.5544771 ]
#  [0.58039826]
#  ...
#  [0.4247951 ]
#  [0.46159256]
#  [0.4210567 ]]

# %%
# Out:
#   File "<ipython-input-50-318110c80eec>", line 5
#     [0. ...
#           ^
# SyntaxError: invalid syntax
